# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import polars as pl
import re

data_path = '/media/chris/4T1/bigFileRepo/physionet.datasets/mimiciv/3.0/hosp/'
DAzero_path = './'

# %%
# functions

def format_ndc_codes(df, column_name='ndc', new_column_name='new_ndc'):
    def format_single_ndc(ndc):
        # Convert scientific notation to integer string
        ndc_str = f'{ndc:.0f}'
        
        # Pad with leading zeros to ensure 11 digits
        ndc_padded = ndc_str.zfill(11)
        
        # Remove the last two digits
        return ndc_padded[:-2]
    
    # Apply the formatting function to the specified column
    df[new_column_name] = df[column_name].apply(format_single_ndc)
    
    return df

def format_ndc_codes_hyphenated(df, column_name='productndc', new_column_name='new_ndc'):
    def format_single_ndc(ndc):
        # Split the NDC code into parts
        parts = ndc.split('-')
        
        if len(parts) != 2:
            return ndc  # Return original if not in expected format
        
        # Pad each part with leading zeros
        part1 = parts[0].zfill(5)
        part2 = parts[1].zfill(4)
        
        # Combine parts without hyphen
        return part1 + part2
    
    # Apply the formatting function to the specified column
    df[new_column_name] = df[column_name].apply(format_single_ndc)
    
    return df

def extract_pharm_class(df, column_name='pharm_classes'):
    def extract_text(text):
        if pd.isna(text):
            return pd.NA
        
        # Use regex to find the text before "[EPC]"
        match = re.search(r'(?:^|,)\s*([^,]+?)\s*\[EPC\]', text)
        
        if match:
            # Strip leading/trailing whitespace
            return match.group(1).strip()
        else:
            # If [EPC] is not found, return NA
            return pd.NA

    # Apply the extraction function to the specified column
    df['extracted_class'] = df[column_name].apply(extract_text)
    
    return df

# %%
# load the mimin iv prescrtiptions data

prescriptions = pl.read_csv(
    DAzero_path + 'data/prescriptions.csv',
    ignore_errors=True
    #n_rows=10000  # Limit to 10,000 rows, adjust as needed
)

#print(prescriptions.columns)

meds = prescriptions.to_pandas()

# %%
# manage the incorrectly formatted NDC codes in the prescription dataframe

meds_formatted = format_ndc_codes(meds)
#print(meds_formatted.head(1))

# %%
# load ndc product table (downloaded from FDA website)
ndc = pd.read_csv(DAzero_path + 'data/NDC_product_table.csv', encoding='latin1')
# convert column names to lowercase
ndc.columns = ndc.columns.str.lower()
print(ndc.columns)
# Out:
# Index(['productid', 'productndc', 'producttypename', 'proprietaryname',
#        'proprietarynamesuffix', 'nonproprietaryname', 'dosageformname',
#        'routename', 'startmarketingdate', 'endmarketingdate',
#        'marketingcategoryname', 'applicationnumber', 'labelername',
#        'substancename', 'active_numerator_strength', 'active_ingred_unit',
#        'pharm_classes', 'deaschedule', 'ndc_exclude_flag',
#        'listing_record_certified_through'],
#       dtype='object')

# %%
# ndc codes also incorrectly formatted in the NDC product table
# correct the codes, to match the prescription dataset

ndc = format_ndc_codes_hyphenated(ndc)
# print(meds_hyphenated)

# %%
# extract the correct info on the drug class from the pharm_classes column
ndc = extract_pharm_class(ndc)
# print(ndc.head(1))

# %%
# now merge meds and ndc
# around 6M rows lost in this step - I think due to old NDC codes not being in the NDC product table (which comes from the FDA)
# I have some old NDC code lists we could use, but hopefully we don't need to do this
print(meds.shape)
meds_merged = pd.merge(meds_formatted, ndc, how='inner', left_on='new_ndc', right_on='new_ndc')
print(meds_merged.shape)
# Out:
# (20292611, 22)
# (14084704, 43)

# %%
# show the extracted classes
print(meds_merged['extracted_class'].unique())
# Out:
# ['Loop Diuretic' 'Anticholinergic'
#  'Human Immunodeficiency Virus Integrase Strand Transfer Inhibitor'
#  'Aldosterone Antagonist' 'beta2-Adrenergic Agonist'
#  'Human Immunodeficiency Virus Nucleoside Analog Reverse Transcriptase Inhibitor'
#  'Anti-coagulant' <NA> 'Rifamycin Antibacterial' 'Osmotic Laxative'
#  'Sulfonamide Antimicrobial' 'Corticosteroid' 'Opioid Agonist'
#  'HMG-CoA Reductase Inhibitor' 'Cholinesterase Inhibitor'
#  'Atypical Antipsychotic' 'Nonergot Dopamine Agonist'
#  'Monoamine Oxidase Inhibitor' 'Cephalosporin Antibacterial'
#  'Serotonin-3 Receptor Antagonist' 'Low Molecular Weight Heparin'
#  'Dopamine-2 Receptor Antagonist' 'Phenothiazine'
#  'Nonsteroidal Anti-inflammatory Drug' 'Proton Pump Inhibitor'
#  'Glycopeptide Antibacterial' 'beta-Adrenergic Blocker'
#  'Angiotensin Converting Enzyme Inhibitor' 'Bisphosphonate'
#  'Calculi Dissolution Agent' 'Nitroimidazole Antimicrobial'
#  'Prostaglandin Analog' 'Benzodiazepine' 'Quinolone Antimicrobial'
#  'Oxytocic' 'Penicillin-class Antibacterial' 'P2Y12 Platelet Inhibitor'
#  'Amide Local Anesthetic' 'Antidote' 'Vitamin K' 'Potassium Salt'
#  'Histamine-2 Receptor Antagonist' '5-alpha Reductase Inhibitor'
#  'Dihydropyridine Calcium Channel Blocker' 'alpha-Adrenergic Blocker'
#  'Insulin Analog' 'Melatonin Receptor Agonist'
#  'Xanthine Oxidase Inhibitor' 'Anti-epileptic Agent' 'Nitrate Vasodilator'
#  'Phosphate Binder' 'Arteriolar Vasodilator'
#  'Central alpha-2 Adrenergic Agonist' 'Serotonin Reuptake Inhibitor'
#  'l-Thyroxine' 'Azole Antifungal' 'Aminoglycoside Antibacterial'
#  'Polyene Antifungal' 'Histamine-1 Receptor Antagonist'
#  'Serotonin and Norepinephrine Reuptake Inhibitor' 'Aminosalicylate'
#  'Typical Antipsychotic' 'Purine Antimetabolite' 'Penem Antibacterial'
#  'Inactivated Clostridium Tetani Vaccine' 'beta Lactamase Inhibitor'
#  'Angiotensin 2 Receptor Blocker' 'Inactivated Pneumococcal Vaccine'
#  'Oxazolidinone Antibacterial' 'Cardiac Glycoside' 'Factor Xa Inhibitor'
#  'Vitamin B12' 'Antihistamine' 'alpha-Adrenergic Agonist'
#  'Thiazide-like Diuretic' 'Platinum-based Drug'
#  'Substance P/Neurokinin-1 Receptor Antagonist' 'General Anesthetic'
#  'Topoisomerase Inhibitor' 'Macrolide Antimicrobial'
#  'N-methyl-D-aspartate Receptor Antagonist' 'Sulfonylurea'
#  'Neuraminidase Inhibitor' 'Carbonic Anhydrase Inhibitor' 'Macrolide'
#  'Calcium Channel Blocker' 'Catecholamine' 'Opioid Antagonist'
#  'Tetracycline-class Drug' 'Methylxanthine'
#  'Leukotriene Receptor Antagonist' 'Non-narcotic Antitussive'
#  'Lincosamide Antibacterial' 'Lipopeptide Antibacterial' 'Muscle Relaxant'
#  'Blood Coagulation Factor' 'Somatostatin Analog' 'Aluminum Complex'
#  'Vitamin C' 'Folate Analog Metabolic Inhibitor'
#  'Parenteral Iron Replacement' 'Aromatase Inhibitor'
#  'Vitamin K Antagonist' 'Barbiturate' 'Antirheumatic Agent'
#  'Herpes Simplex Virus Nucleoside Analog DNA Polymerase Inhibitor'
#  'Radiographic Contrast Agent' 'Aminoketone' 'Calcitonin'
#  'Tetracycline-class Antibacterial' 'Human Serum Albumin' 'Antiarrhythmic'
#  'Thiazide Diuretic' 'Alkaloid' 'alpha-1 Adrenergic Agonist'
#  'Central Nervous System Stimulant' 'Tricyclic Antidepressant'
#  'Live Attenuated Varicella Zoster Virus Vaccine'
#  'RNA Synthetase Inhibitor Antibacterial' 'Protease Inhibitor'
#  'Provitamin D2 Compound' 'Bile Acid' 'Vinca Alkaloid' 'Alkylating Drug'
#  'Adenosine Receptor Agonist' 'Leukocyte Growth Factor'
#  'Cholinergic Muscarinic Antagonist' 'Tetracycline-class Antimicrobial'
#  'Echinocandin Antifungal' 'Neprilysin Inhibitor'
#  'Prostacycline Vasodilator' 'Nondepolarizing Neuromuscular Blocker'
#  'Nitrofuran Antibacterial' 'Mood Stabilizer'
#  'gamma-Aminobutyric Acid-ergic Agonist'
#  'Dietary Cholesterol Absorption Inhibitor' 'Heparin Reversal Agent'
#  'Androgen' 'Plasma Volume Expander'
#  'Cytomegalovirus Nucleoside Analog DNA Polymerase Inhibitor'
#  'Human Immunoglobulin G' 'Antimalarial' 'Skin Test Antigen'
#  'Antimetabolite Immunosuppressant'
#  'Calcineurin Inhibitor Immunosuppressant'
#  'Peroxisome Proliferator Receptor alpha Agonist' 'Bile Acid Sequestrant'
#  'Antidiarrheal' 'Biguanide' 'Adrenocorticotropic Hormone'
#  'Aromatic Amino Acid' 'Sodium-Glucose Cotransporter 2 Inhibitor'
#  'Monobactam Antibacterial'
#  'Human Immunodeficiency Virus 1 Non-Nucleoside Analog Reverse Transcriptase Inhibitor'
#  'Retinoid' 'Anti-anginal' 'l-Triiodothyronine' 'Carnitine Analog'
#  'Ergot Derivative' 'Nucleoside Metabolic Inhibitor'
#  'Interleukin-6 Receptor Antagonist'
#  'CD19-directed Chimeric Antigen Receptor' 'Cytochrome P450 3A Inhibitor'
#  'Interleukin-2 Receptor Blocking Antibody' 'Osmotic Diuretic'
#  'Anthracycline Topoisomerase Inhibitor' 'Guanylate Cyclase-C Agonist'
#  'SARS-CoV-2 Nucleotide Analog RNA Polymerase Inhibitor'
#  'Erythropoiesis-stimulating Agent' 'Factor VIII Activator'
#  'Antiparasitic' 'Collagen-specific Enzyme'
#  'Noncompetitive AMPA Glutamate Receptor Antagonist'
#  'Proteasome Inhibitor' 'Thyroid Hormone Synthesis Inhibitor'
#  'Estrogen Agonist/Antagonist' 'Interferon alpha'
#  'Phosphodiesterase 3 Inhibitor' 'Vasopressin V2 Receptor Antagonist'
#  'Antiemetic' 'Insulin' 'Estrogen' 'Thiazolidinedione'
#  'Tumor Necrosis Factor Blocker' 'Local Anesthetic'
#  'Polymyxin-class Antibacterial' 'Antifibrinolytic Agent'
#  'Depolarizing Neuromuscular Blocker' 'Prostaglandin E1 Analog'
#  'Live Attenuated Measles Virus Vaccine' 'Amino Acid' 'Cannabinoid'
#  'Progestin' 'Partial Opioid Agonist' 'Antimetabolite'
#  'Calcium-sensing Receptor Agonist' 'mTOR Inhibitor Immunosuppressant'
#  'Dipeptidyl Peptidase 4 Inhibitor' 'Vasoconstrictor'
#  'Oxidation-Reduction Agent' 'Folate Analog' 'beta-Adrenergic Agonist'
#  'Kinase Inhibitor' 'Antimycobacterial' 'Interleukin-23 Antagonist'
#  'Cholinergic Receptor Agonist' 'Potassium-sparing Diuretic'
#  'Amphenicol-class Antibacterial' 'Progesterone'
#  'Copper Absorption Inhibitor' 'Sulfone' 'Cytoprotective Agent'
#  'Microtubule Inhibitor' 'Vitamin D3 Analog' 'Sympathomimetic-like Agent'
#  'Serotonin-1b and Serotonin-1d Receptor Agonist' 'Antiprotozoal'
#  'CD20-directed Cytolytic Antibody' 'Lipid-based Polyene Antifungal'
#  'Respiratory Syncytial Virus Anti-F Protein Monoclonal Antibody'
#  'Vitamin D2 Analog' 'Lipid Emulsion' 'Thyroid Stimulating Hormone'
#  'Vasodilator' 'Immunoglobulin G' 'Norepinephrine Reuptake Inhibitor'
#  'Endoglycosidase' 'Human Immunoglobulin' 'BCL-2 Inhibitor'
#  'Inactivated Meningococcal Vaccine'
#  'Inactivated Hepatitis A Virus Vaccine' 'Acetylcholine Release Inhibitor'
#  'Influenza A M2 Protein Inhibitor'
#  'Catechol-O-Methyltransferase Inhibitor' 'Vitamin D Analog'
#  'Phosphodiesterase 5 Inhibitor' 'Blood Viscosity Reducer'
#  'Recombinant Human Deoxyribonuclease 1' 'Opioid Agonist/Antagonist'
#  'Benzodiazepine Antagonist' 'Nucleoside Analog Antifungal'
#  'Epidermal Growth Factor Receptor Antagonist' 'Pyrethroid'
#  'Ester Local Anesthetic' 'Vascular Endothelial Growth Factor Inhibitor'
#  'Thrombopoietin Receptor Agonist'
#  'Hepatitis C Virus Nucleotide Analog NS5B Polymerase Inhibitor'
#  'Sulfonamide Antibacterial' 'RANK Ligand Inhibitor'
#  'Hepatitis C Virus NS5A Inhibitor' 'Nucleoside Analog Antiviral'
#  'Platelet Aggregation Inhibitor'
#  'Hepatitis B Virus Nucleoside Analog Reverse Transcriptase Inhibitor'
#  'Skeletal Muscle Relaxant'
#  'Cytomegalovirus DNA Terminase Complex Inhibitor' 'Thalidomide Analog'
#  'CD33-directed Immunoconjugate' 'Chloride Channel Activator'
#  'Pyrophosphate Analog DNA Polymerase Inhibitor'
#  'Cholinergic Muscarinic Agonist' 'Selective T Cell Costimulation Blocker'
#  'Orexin Receptor Antagonist' 'GLP-1 Receptor Agonist'
#  'Direct Thrombin Inhibitor' 'Vitamin B6 Analog'
#  'Estrogen Receptor Antagonist' 'Platelet-reducing Agent'
#  'Dihydrofolate Reductase Inhibitor Antimalarial'
#  'Rifamycin Antimycobacterial' 'Interleukin-1 Receptor Antagonist'
#  'Anti-IgE' 'CCR5 Co-receptor Antagonist' 'Integrin Receptor Antagonist'
#  'Hematopoietic Stem Cell Mobilizer' 'CD52-directed Cytolytic Antibody'
#  'Interleukin-4 Receptor alpha Antagonist' 'Janus Kinase Inhibitor'
#  'Iron Chelator' 'Macrolide Antibacterial'
#  'CD38-directed Cytolytic Antibody'
#  'Programmed Death Receptor-1 Blocking Antibody'
#  'Androgen Receptor Inhibitor' 'Mast Cell Stabilizer'
#  'Lymphocyte Growth Factor' 'Endothelin Receptor Antagonist' 'Glinide'
#  'Anthelmintic' 'alpha-Glucosidase Inhibitor'
#  'Selective T Cell Costimulation Modulator'
#  'Cholinergic Nicotinic Agonist' 'CD30-directed Immunoconjugate'
#  'Parathyroid Hormone Analog' 'Ergotamine Derivative' 'Actinomycin'
#  'Renin Inhibitor' 'Plasma Kallikrein Inhibitor' 'Potassium Binder'
#  'Human C1 Esterase Inhibitor' 'Bradykinin B2 Receptor Antagonist'
#  'Aldehyde Dehydrogenase Inhibitor' 'Pyrimidine Analog'
#  'Porphyrin Precursor' 'Cholinesterase Reactivator'
#  'Inactivated Hepatitis B Virus Vaccine' 'Lipoglycopeptide Antibacterial'
#  'Vesicular Monoamine Transporter 2 Inhibitor' 'Allylamine Antifungal'
#  'Isocitrate Dehydrogenase 2 Inhibitor'
#  'Hyperpolarization-activated Cyclic Nucleotide-gated Channel Blocker'
#  'Phosphodiesterase 4 Inhibitor'
#  'Orthopoxvirus VP37 Envelope Wrapping Protein Inhibitor'
#  'Complement Inhibitor' 'Dihydrofolate Reductase Inhibitor Antibacterial'
#  'HER2/neu Receptor Antagonist' 'Methylated Sulfonamide Antibacterial'
#  'Benzothiazole' 'Progesterone Agonist/Antagonist'
#  'Photoactivated Radical Generator' 'Diagnostic Dye'
#  'Herpesvirus Nucleoside Analog DNA Polymerase Inhibitor'
#  'Histone Deacetylase Inhibitor' 'Progestin Antagonist'
#  'CTLA-4-directed Blocking Antibody' 'Potassium Channel Blocker'
#  'Poly(ADP-Ribose) Polymerase Inhibitor' 'Inactivated Poliovirus Vaccine'
#  'Vascular Endothelial Growth Factor Receptor 2 Antagonist'
#  'Polyene Antimicrobial' 'Human Platelet-derived Growth Factor'
#  'Humanized Monoclonal Antibody Fragment' 'Cholecystokinin Analog'
#  'SLAMF7-directed Immunostimulatory Antibody' 'Carboxypeptidase'
#  'Hydrolytic Lysosomal Glucocerebroside-specific Enzyme'
#  'B Lymphocyte Stimulator-specific Inhibitor']

# %%
# create list of extracted classes unique values
extracted_classes = meds_merged['extracted_class'].unique()
# remove nan
extracted_classes = extracted_classes[~pd.isna(extracted_classes)]
print(extracted_classes)

# create a dictionary of extracted classes
class_dict = dict(zip(extracted_classes, range(len(extracted_classes))))
print(class_dict)

# save out extracted classes
class_df = pd.DataFrame(extracted_classes, columns=['class'])
class_df.to_csv(DAzero_path + 'data/extracted_classes.csv', index=False)

# %%
# classes of interest
# NB corticosteroids only have a single class
antibacterial = meds_merged[meds_merged['extracted_class'].str.contains('Antibacterial', na=False)]['extracted_class'].unique()
antimicrobial = meds_merged[meds_merged['extracted_class'].str.contains('Antimicrobial', na=False)]['extracted_class'].unique()
antifungal = meds_merged[meds_merged['extracted_class'].str.contains('Antifungal', na=False)]['extracted_class'].unique()

# %%
# reset the meds_merged index
meds_merged = meds_merged.reset_index(drop=True)

# create a smaller dataframe with only the relevant columns
meds_extract = meds_merged[['subject_id', 'hadm_id', 'starttime', 'drug', 'prod_strength',
       'dose_val_rx', 'dose_unit_rx',
       'doses_per_24_hrs', 'extracted_class']]

print(meds_extract['extracted_class'].value_counts())
# Out:
# extracted_class
# Anti-coagulant                                1585020
# Osmotic Laxative                              1570737
# Opioid Agonist                                1081605
# Potassium Salt                                 611669
# Insulin Analog                                 571405
#                                                ...
# Progestin Antagonist                                1
# Cholinesterase Reactivator                          1
# Photoactivated Radical Generator                    1
# Thyroid Stimulating Hormone                         1
# B Lymphocyte Stimulator-specific Inhibitor          1
# Name: count, Length: 334, dtype: int64

# %%
# save out the extracted data
meds_extract.to_csv(DAzero_path + 'data/mimic_prescriptions_extracted.csv', index=False)

# %%
# create mapping table for optimal
meds_merged.head()
# drop any rows where column ['pharm_classes'] is nan
## NB these NANs are due to the merge, where the NDC code is not in the NDC product table
## this is due to old NDC codes being used in the prescriptions dataset in MIMIC IV
print(meds_merged.shape)
meds_merged = meds_merged.dropna(subset=['pharm_classes'])
print(meds_merged.shape)

# convert columns 'drug' and 'extracted_class' to lower case
meds_merged['drug'] = meds_merged['drug'].str.lower()
meds_merged['extracted_class'] = meds_merged['extracted_class'].str.lower()
# Out:
# (14084704, 43)
# (11810429, 43)

# %%
# create a mapping table of unique drug to extracted class
mapping_table = meds_merged[['drug', 'extracted_class']].drop_duplicates()
mapping_table.head()
print(mapping_table.shape)

# order the mapping table by extracted class
mapping_table = mapping_table.sort_values(by='extracted_class')
# save out the mapping table
mapping_table.to_csv(DAzero_path + 'data/mapping_table.csv', index=False)
